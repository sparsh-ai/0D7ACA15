# %% [markdown]
# ### Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Open Image

# %%
image = cv2.imread('images/car_plate.jpg')
fix_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %% [markdown]
# ### Create Classifier

# %%
plate_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_plate_number.xml')

# %% [markdown]
# ### It's a Kind of Magic

# %%
def detect_plates(fix_img):
    plate_rects = plate_classifier.detectMultiScale(fix_img)
    
    for (x, y, w, h) in plate_rects:
        cv2.rectangle(fix_img,
                     (x,y),
                     (x+w, y+h),
                     (255,0,0),
                     10)
        
    return fix_img

# %%
result = detect_plates(fix_img)
plt.imshow(result)
